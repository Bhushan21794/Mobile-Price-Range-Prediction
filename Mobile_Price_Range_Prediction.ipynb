# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhushan21794/Mobile-Price-Range-Prediction/blob/main/Mobile_Price_Range_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **INTRODUCTION**
#
# In the competitive mobile phone market companies want to understand sales data of mobile phones and factors which drive the prices.
#
# The objective is to find out some relation between features of a mobile phone(eg:- RAM, Internal Memory, etc) and its selling price. In this problem, we do not have to predict the actual price but a price range indicating how high the price is.

# %% [markdown]
# # **Data Description**
#
# **Battery_power** - Total energy a battery can store in one time measured in mAh
#
# **Blue** - Has bluetooth or not
#
# **Clock_speed** - speed at which microprocessor executes instructions
#
# **Dual_sim** - Has dual sim support or not
#
# **Fc** - Front Camera mega pixels
#
# **Four_g** - Has 4G or not
#
# **Int_memory** - Internal Memory in Gigabytes
#
# **M_dep** - Mobile Depth in cm
#
# **Mobile_wt** - Weight of mobile phone
#
# **N_cores** - Number of cores of processor
#
# **Pc** - Primary Camera mega pixels
#
# **Px_height** - Pixel Resolution Height
#
# **Px_width** - Pixel Resolution Width
#
# **Ram** - Random Access Memory in Mega Bytes
#
# **Sc_h** - Screen Height of mobile in cm
#
# **Sc_w** - Screen Width of mobile in cm
#
# **Talk_time** - longest time that a single battery charge will last when you are
#
# **Three_g** - Has 3G or not
#
# **Touch_screen** - Has touch screen or not
#
# **Wifi** - Has wifi or not
#
# **Price_range**- This is the target variable with value of 0(low cost), 1(medium cost),2(high cost) and 3(very high cost).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Alma better Projects/Supervised ML Classification - Mobile Price Range Prediction/data_mobile_price_range.csv')

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.tail()
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 1995    0.8        106        6  ...       1222      1890   668    13     4
# 1996    0.2        187        4  ...        915      1965  2032    11    10
# 1997    0.7        108        8  ...        868      1632  3057     9     1
# 1998    0.1        145        5  ...        336       670   869    18    10
# 1999    0.9        168        6  ...        483       754  3919    19     4
#
#       talk_time  three_g  touch_screen  wifi  price_range
# ...

# %%
df.shape
# Out:
# (2000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                 count        mean          std    min      25%     50%  \
# battery_power  2000.0  1238.51850   439.418206  501.0   851.75  1226.0
# blue           2000.0     0.49500     0.500100    0.0     0.00     0.0
# clock_speed    2000.0     1.52225     0.816004    0.5     0.70     1.5
# dual_sim       2000.0     0.50950     0.500035    0.0     0.00     1.0
# fc             2000.0     4.30950     4.341444    0.0     1.00     3.0
# four_g         2000.0     0.52150     0.499662    0.0     0.00     1.0
# int_memory     2000.0    32.04650    18.145715    2.0    16.00    32.0
# m_dep          2000.0     0.50175     0.288416    0.1     0.20     0.5
# mobile_wt      2000.0   140.24900    35.399655   80.0   109.00   141.0
# n_cores        2000.0     4.52050     2.287837    1.0     3.00     4.0
# pc             2000.0     9.91650     6.064315    0.0     5.00    10.0
# px_height      2000.0   645.10800   443.780811    0.0   282.75   564.0
# ...

# %% [markdown]
#  Minimum value of px_height & Sc_w can not be zero so replacing 0 with mean
# values

# %%
print(len(df[df.sc_w == 0]))
print(len(df[df.px_height == 0]))
# Out:
# 180
# 2

# %%
df['sc_w'][df[df.sc_w == 0].index] = df.sc_w.mean()
df['px_height'][df[df.px_height == 0].index] = df.px_height.mean()
# Out:
# <ipython-input-13-9b028ff479a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sc_w'][df[df.sc_w == 0].index] = df.sc_w.mean()
# <ipython-input-13-9b028ff479a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['px_height'][df[df.px_height == 0].index] = df.px_height.mean()

# %%
len(df[df.duplicated()])
# Out:
# 0

# %%
df.nunique()
# Out:
# battery_power    1094
# blue                2
# clock_speed        26
# dual_sim            2
# fc                 20
# four_g              2
# int_memory         63
# m_dep              10
# mobile_wt         121
# n_cores             8
# pc                 21
# px_height        1137
# px_width         1109
# ram              1562
# sc_h               15
# sc_w               19
# talk_time          19
# three_g             2
# touch_screen        2
# wifi                2
# price_range         4
# dtype: int64

# %% [markdown]
# # **Exploratory Data Analysis**

# %%
sns.set()
price_plot=df['price_range'].value_counts().plot(kind='bar' , color = 'orange')
plt.xlabel('price_range')
plt.ylabel('count')
plt.show()

# %%
sns.set(rc={'figure.figsize' :(5,5)})
ax=sns.barplot(x='price_range' , y='battery_power' , data=df)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(5,5))
x=df['blue']
y=df['blue'].value_counts()
sns.barplot(x,y,ax=ax)
plt.xlabel("Bluetooth")
plt.ylabel("Counts")
plt.title("Bluetooth connectivity vs count")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig,ax=plt.subplots(figsize=(5,5))
x=df['blue']
y=df['price_range']
sns.barplot(x,y,ax=ax)
plt.xlabel("Bluetooth")
plt.ylabel("price_range")
plt.title("Bluetooth connectivity vs price_range")
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.plot(x='price_range', y='ram',kind='scatter')
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df.plot(x='price_range' , y='fc' ,kind='scatter')
plt.show()
# Out:
# WARNING:matplotlib.axes._axes:*c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
fig, axs = plt.subplots(1,2,figsize=(12,5))
sns.kdeplot(data=df, x='n_cores', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range' ,y='n_cores' , ax=axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(12,5))
sns.kdeplot(data=df, x='mobile_wt', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range' ,y='mobile_wt' , ax=axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1,2,figsize=(12,5))
sns.kdeplot(data=df, x='sc_h', hue='price_range', ax=axs[0])
sns.boxplot(data=df, x='price_range' ,y='sc_h' , ax=axs[1])
plt.show()

# %%
connectivity_features = ['four_g' , 'three_g']

# %%
for col in connectivity_features:

  fig, (ax1, ax2) = plt.subplots(ncols = 2 , figsize = (10,5))

  df[col].value_counts().plot.pie (autopct='%1.1f%%' , ax = ax1, shadow=True , labeldistance=None)
  ax1.set_title('Distribution by price range')
  ax1.legend(['support','Does not support'])
  sns.countplot(x= col,hue='price_range' , data = df,ax=ax2,color = 'orange')
  ax2.set_title('Distribution by price range')
  ax2.set_xlabel(col)
  ax2.legend(['Low Cost','Medium Cost','High Cost' , 'Very High Cost'])
  ax2.set_xticklabels(['Does not support' , 'Support'])

# %% [markdown]
# # **Checking the distribution of all the independent variables :**

# %%
n_features = df.describe().columns
n_features
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
plt.figure(figsize = (10,8))
for col in n_features[0:20]:
  sns.distplot(df[col],color='orange')
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # **Transformation of all independent variables :**

# %%
features_1 = ['fc','clock_speed','px_height','sc_w']

# %%
plt.figure(figsize = (10,8))
for col in features_1:
  sns.distplot(np.sqrt(df[col]),color = 'Orange')
  plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # **Checking for Multi-collinearity**

# %%
correlation = df.corr()
plt.figure(figsize=(20,15))
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')

# %% [markdown]
# From above heatmap we see ram & price_range shows high correlation which is good, it signifies that RAM play major deciding factor in estimating price range.

# %% [markdown]
# There is some collinearity in feature pairs pc & fc also px_width & px_height both correlation are justified since there are good chances that if front camera of phone is good,the back camera would also be good.

# %% [markdown]
# ## **Looking for Outliers**

# %%
plt.figure(figsize=(25,10))
for index , item in enumerate ([i for i in df.describe().columns.to_list()]):
  plt.subplot(5,5,index+1)
  sns.boxplot(df[item])
  print("\n")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# From above boxplots we see there are not too much outliers.

# %% [markdown]
# ## **Logistics Regression**

# %%
x = df.drop(['price_range'],axis = 1)
y = df['price_range']

# %%
print(x.shape,y.shape)
# Out:
# (2000, 20) (2000,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaler = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x_scaler , y , test_size = 0.20 , random_state = 42)

# %%
print(x_train.shape , y_train.shape)
# Out:
# (1600, 20) (1600,)

# %%
from sklearn.linear_model import LogisticRegression
Ir = LogisticRegression()
Ir.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
log_pred = Ir.predict(x_test)

# %%
from sklearn.metrics import classification_report , confusion_matrix,accuracy_score

# %%
print(confusion_matrix(log_pred,y_test))
# Out:
# [[105   1   0   0]
#  [  0  86   9   0]
#  [  0   4  77   3]
#  [  0   0   6 109]]

# %%
print(classification_report(log_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00       106
#            1       0.95      0.91      0.92        95
#            2       0.84      0.92      0.88        84
#            3       0.97      0.95      0.96       115
#
#     accuracy                           0.94       400
#    macro avg       0.94      0.94      0.94       400
# weighted avg       0.95      0.94      0.94       400

# %%
print(accuracy_score(y_test,log_pred))
# Out:
# 0.9425

# %% [markdown]
# ## **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier()

# %%
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
ran_pred = classifier.predict(x_test)

# %%
print(accuracy_score(ran_pred,y_test))
# Out:
# 0.885

# %%
print(classification_report(ran_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       107
#            1       0.85      0.86      0.85        90
#            2       0.84      0.79      0.81        98
#            3       0.88      0.94      0.91       105
#
#     accuracy                           0.89       400
#    macro avg       0.88      0.88      0.88       400
# weighted avg       0.88      0.89      0.88       400

# %% [markdown]
# ## **Hyperparameter Tunning on RandomForest Model**

# %%
from sklearn.model_selection import GridSearchCV
params = {'n_estimators' : [10,50,60,80,100,200,300],'max_depth':[10,20,30,40],
          'max_leaf_nodes':[10,20,40]
          }
gsv = GridSearchCV(classifier,param_grid = params, scoring = 'accuracy' , cv = 5)

# %%
gsv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [10, 20, 30, 40],
#                          'max_leaf_nodes': [10, 20, 40],
#                          'n_estimators': [10, 50, 60, 80, 100, 200, 300]},
#              scoring='accuracy')

# %%
print(gsv.best_params_)
# Out:
# {'max_depth': 40, 'max_leaf_nodes': 40, 'n_estimators': 300}

# %%
print(gsv.best_score_)
# Out:
# 0.8574999999999999

# %%
ran_pred2 = gsv.predict(x_test)

# %%
print(confusion_matrix(ran_pred2,y_test))
# Out:
# [[101   8   0   0]
#  [  4  74  10   0]
#  [  0   9  73  11]
#  [  0   0   9 101]]

# %%
print(accuracy_score(ran_pred2,y_test))
# Out:
# 0.8725

# %%
print(classification_report(ran_pred2,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94       109
#            1       0.81      0.84      0.83        88
#            2       0.79      0.78      0.79        93
#            3       0.90      0.92      0.91       110
#
#     accuracy                           0.87       400
#    macro avg       0.87      0.87      0.87       400
# weighted avg       0.87      0.87      0.87       400

# %%
feature_importance = pd.DataFrame({'Feature':x.columns,
                                   'score':classifier.feature_importances_}).sort_values(by='score', ascending = False).reset_index(drop=True)

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax = sns.barplot(x=feature_importance['score'],y=feature_importance['Feature'], color = 'orange')
plt.show()

# %% [markdown]
# ## **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc_pred = dtc.predict(x_test)

# %%
print(confusion_matrix(dtc_pred , y_test))
# Out:
# [[ 92   7   0   0]
#  [ 13  74  16   0]
#  [  0  10  63  12]
#  [  0   0  13 100]]

# %%
print(classification_report(dtc_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90        99
#            1       0.81      0.72      0.76       103
#            2       0.68      0.74      0.71        85
#            3       0.89      0.88      0.89       113
#
#     accuracy                           0.82       400
#    macro avg       0.82      0.82      0.82       400
# weighted avg       0.82      0.82      0.82       400

# %%
print(accuracy_score(dtc_pred,y_test))
# Out:
# 0.8225

# %% [markdown]
# ## **Hyperparameter Tunning on decision Tree Model**

# %%
from sklearn.model_selection import GridSearchCV
grid = GridSearchCV(dtc, param_grid = {'max_depth': (5,30) , 'max_leaf_nodes':(10,100)} , scoring = 'accuracy' , cv=5 , verbose = 24)
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5; 1/4] START max_depth=5, max_leaf_nodes=10..............................
# [CV 1/5; 1/4] END max_depth=5, max_leaf_nodes=10;, score=0.800 total time=   0.0s
# [CV 2/5; 1/4] START max_depth=5, max_leaf_nodes=10..............................
# [CV 2/5; 1/4] END max_depth=5, max_leaf_nodes=10;, score=0.819 total time=   0.0s
# [CV 3/5; 1/4] START max_depth=5, max_leaf_nodes=10..............................
# [CV 3/5; 1/4] END max_depth=5, max_leaf_nodes=10;, score=0.803 total time=   0.0s
# [CV 4/5; 1/4] START max_depth=5, max_leaf_nodes=10..............................
# [CV 4/5; 1/4] END max_depth=5, max_leaf_nodes=10;, score=0.772 total time=   0.0s
# [CV 5/5; 1/4] START max_depth=5, max_leaf_nodes=10..............................
# [CV 5/5; 1/4] END max_depth=5, max_leaf_nodes=10;, score=0.794 total time=   0.0s
# [CV 1/5; 2/4] START max_depth=5, max_leaf_nodes=100.............................
# ...

# %%
dtc_pred2 = grid.predict(x_test)

# %%
print(confusion_matrix(dtc_pred2 , y_test))
# Out:
# [[ 91   6   0   0]
#  [ 14  76  13   0]
#  [  0   9  64  12]
#  [  0   0  15 100]]

# %%
print(classification_report(dtc_pred2 , y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90        97
#            1       0.84      0.74      0.78       103
#            2       0.70      0.75      0.72        85
#            3       0.89      0.87      0.88       115
#
#     accuracy                           0.83       400
#    macro avg       0.82      0.82      0.82       400
# weighted avg       0.83      0.83      0.83       400

# %%
print(accuracy_score(y_test, dtc_pred2))
# Out:
# 0.8275

# %%
feature_importance = pd.DataFrame({'Feature':x.columns,
                                   'score':dtc.feature_importances_}).sort_values(by='score', ascending = False).reset_index(drop=True)

# %%
fig,ax = plt.subplots(figsize=(12,8))
ax = sns.barplot(x=feature_importance['score'],y=feature_importance['Feature'], color = 'orange')
plt.show()

# %% [markdown]
# ## **Support Vector Machine**

# %%
from sklearn import svm
from sklearn.svm import SVC

# %%
svmachine = SVC()

# %%
svmachine.fit(x_train, y_train)
# Out:
# SVC()

# %%
svm_predict = svmachine.predict(x_test)

# %%
print(confusion_matrix(svm_predict,y_test))
# Out:
# [[100   5   0   0]
#  [  5  80  13   0]
#  [  0   6  72  17]
#  [  0   0   7  95]]

# %%
print(classification_report(svm_predict,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       105
#            1       0.88      0.82      0.85        98
#            2       0.78      0.76      0.77        95
#            3       0.85      0.93      0.89       102
#
#     accuracy                           0.87       400
#    macro avg       0.87      0.86      0.86       400
# weighted avg       0.87      0.87      0.87       400

# %%
print(accuracy_score(svm_predict,y_test))
# Out:
# 0.8675

# %% [markdown]
# ## **Hyperparameter Tunning on Support Vector Machine Model**

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'gamma' : [.1,.5,.25,1],
              'kernel':['rbf' , 'poly' , 'sigmoid' , 'linear']}
GS = GridSearchCV(SVC(),param_grid , cv= 5)

# %%
GS.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'gamma': [0.1, 0.5, 0.25, 1],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']})

# %%
print(GS.best_score_)
print(GS.best_params_)
# Out:
# 0.9306249999999998
# {'gamma': 0.1, 'kernel': 'linear'}

# %%
svm_predict_2 = GS.predict(x_test)

# %%
print(confusion_matrix(svm_predict_2,y_test))
# Out:
# [[103   0   0   0]
#  [  2  91   5   0]
#  [  0   0  83   5]
#  [  0   0   4 107]]

# %%
print(classification_report(svm_predict_2,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       103
#            1       1.00      0.93      0.96        98
#            2       0.90      0.94      0.92        88
#            3       0.96      0.96      0.96       111
#
#     accuracy                           0.96       400
#    macro avg       0.96      0.96      0.96       400
# weighted avg       0.96      0.96      0.96       400

# %%
print(accuracy_score(svm_predict_2,y_test))
# Out:
# 0.96

# %%
models = ['Logistic Regression' , 'random forest' , 'decision tree' , 'support vector machine']
acc_scores = [0.9425 , 0.89, 0.8375, 0.96]

plt.figure(figsize= (15,8))
plt.bar(models,acc_scores , color = ['blue', 'yellow' , 'orange' , 'cyan' , 'red' , 'violet'],)
plt.ylabel("accuracy scores")
plt.title("ModelWise Accuracy")
plt.show()

# %% [markdown]
# ## After Training our dataset with four different models, We conclude that support vector machine model & Logistic Regression model are the best model for our dataset.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1.Ram , Battery_power features were found to be the most relevant features for
# predicting price range of mobiles.
#
# 2.Support vector machine model give better accuracy for given dataset
#
# 3.From EDA we can see that there are mobile phones in 4 price ranges. The number of elements is almost similar.
#
# 4.Half of devices have bluetooth connectivity & another half of devices dont have bluetooth connectivity.
#
# 5.There is a gradual increase in battery as the price range increases
#
# 6.Ram has continuous increase with price range while moving from Low cost to Very high cost
#
# 7.From all the above experiments we can conclude that logistic regression and SVM with using hyperparameters we got the best results.
